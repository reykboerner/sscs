# %% [markdown]
# # Julia test notebook
#
# If the following cells run without error, you should be good to go for the Julia exercises.
#
# Select a Julia kernel in the top right.
#
# Note that you need an internet connection to install any missing packages. This code was tested with Julia v12.

# %%
using Pkg
Pkg.activate(".")
Pkg.add("DynamicalSystems")
Pkg.add("NetworkDynamics")
Pkg.add("PyPlot") # alternatively, "Plots" or "CairoMakie" for visualizations
Pkg.add("Random")

# %%
using NetworkDynamics
using DynamicalSystems
